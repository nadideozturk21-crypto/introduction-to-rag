# %%
import os
from dotenv import load_dotenv

load_dotenv()

# This will print True if it found a .env file, False if it didn't
import pathlib
print(".env file exists here:", pathlib.Path('.env').exists())

# This will check if the key is actually loaded into memory
print("API Key loaded successfully:", "OPENAI_API_KEY" in os.environ)
