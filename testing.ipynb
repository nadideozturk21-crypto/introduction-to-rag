# %%
import os
import sys
from dotenv import load_dotenv

# 1. This forces Python to look in the workspace root directory in Codespaces
workspace_root = '/workspaces/introduction-to-rag'
env_path = os.path.join(workspace_root, '.env')

# 2. Explicitly load from that absolute path
load_dotenv(dotenv_path=env_path)

# 3. Check again
print("Does the file exist at this path?", os.path.exists(env_path))
print("API Key loaded successfully:", "OPENAI_API_KEY" in os.environ)
# Out:
# Does the file exist at this path? False
# API Key loaded successfully: False
